# %%
# First, install the pandas_datareader package and yfinance
# !pip install pandas_datareader


# Then import the libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import pandas_datareader as data
plt.style.use('fivethirtyeight')
# %matplotlib inline

# %%
#installing yfinance
# !pip install yfinance
import yfinance as yf
import datetime as dt

# %%
stock = "TATAMOTORS.NS"
start = dt.datetime(2000,1,1)
end = dt.datetime.now()

df = yf.download(stock, start, end)
df.head()
# Out:
# /tmp/ipython-input-1780296055.py:5: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(stock, start, end)
# [*********************100%***********************]  1 of 1 completed
# Price              Close          High           Low          Open  \
# Ticker     TATAMOTORS.NS TATAMOTORS.NS TATAMOTORS.NS TATAMOTORS.NS
# Date
# 2000-01-03     32.449177     32.524032     31.049410     31.049410
# 2000-01-04     31.169176     32.786021     30.839818     32.486604
# 2000-01-05     31.925192     32.606361     29.043314     29.043314
# 2000-01-06     33.250103     34.417822     32.187175     32.187175
# 2000-01-07     35.914906     35.914906     33.399814     33.534553
#
# Price             Volume
# Ticker     TATAMOTORS.NS
# Date
# 2000-01-03       3528277
# 2000-01-04       3544397
# 2000-01-05       5849540
# 2000-01-06      10274966
# 2000-01-07      11477451

# %%
df.tail()
# Out:
# Price              Close          High           Low          Open  \
# Ticker     TATAMOTORS.NS TATAMOTORS.NS TATAMOTORS.NS TATAMOTORS.NS
# Date
# 2025-08-18    676.000000    685.000000    672.900024    677.000000
# 2025-08-19    700.250000    703.349976    673.099976    676.750000
# 2025-08-20    689.599976    700.799988    689.000000    700.250000
# 2025-08-21    685.400024    694.950012    685.000000    694.000000
# 2025-08-22    680.299988    691.500000    678.599976    685.900024
#
# Price             Volume
# Ticker     TATAMOTORS.NS
# Date
# 2025-08-18      14226172
# 2025-08-19      19440384
# 2025-08-20      10050137
# 2025-08-21       8432614
# 2025-08-22       6429718

# %%
df.shape
# Out:
# (6400, 5)

# %%
df.info
# Out:
# <bound method DataFrame.info of Price              Close          High           Low          Open  \
# Ticker     TATAMOTORS.NS TATAMOTORS.NS TATAMOTORS.NS TATAMOTORS.NS
# Date
# 2000-01-03     32.449177     32.524032     31.049410     31.049410
# 2000-01-04     31.169176     32.786021     30.839818     32.486604
# 2000-01-05     31.925192     32.606361     29.043314     29.043314
# 2000-01-06     33.250103     34.417822     32.187175     32.187175
# 2000-01-07     35.914906     35.914906     33.399814     33.534553
# ...                  ...           ...           ...           ...
# 2025-08-18    676.000000    685.000000    672.900024    677.000000
# 2025-08-19    700.250000    703.349976    673.099976    676.750000
# 2025-08-20    689.599976    700.799988    689.000000    700.250000
# 2025-08-21    685.400024    694.950012    685.000000    694.000000
# 2025-08-22    680.299988    691.500000    678.599976    685.900024
#
# Price             Volume
# Ticker     TATAMOTORS.NS
# ...

# %%
df.isnull().sum()
# Out:
# Price   Ticker
# Close   TATAMOTORS.NS    0
# High    TATAMOTORS.NS    0
# Low     TATAMOTORS.NS    0
# Open    TATAMOTORS.NS    0
# Volume  TATAMOTORS.NS    0
# dtype: int64

# %%
df.describe()
# Out:
# Price          Close          High           Low          Open        Volume
# Ticker TATAMOTORS.NS TATAMOTORS.NS TATAMOTORS.NS TATAMOTORS.NS TATAMOTORS.NS
# count    6400.000000   6400.000000   6400.000000   6400.000000  6.400000e+03
# mean      254.280471    258.243118    250.644411    254.724832  1.629354e+07
# std       226.105879    228.899388    223.650671    226.613115  2.097005e+07
# min         8.966139      9.255862      8.775532      8.844151  0.000000e+00
# 25%        75.683451     77.084812     73.779190     75.780454  6.188420e+06
# 50%       176.378395    179.828124    173.071609    176.328635  1.016393e+07
# 75%       400.843498    406.840451    395.890695    401.950624  1.784683e+07
# max      1151.945801   1168.949630   1135.536938   1157.051852  3.905778e+08

# %%
df = df.reset_index()
df.head()
# Out:
# Price        Date         Close          High           Low          Open  \
# Ticker            TATAMOTORS.NS TATAMOTORS.NS TATAMOTORS.NS TATAMOTORS.NS
# 0      2000-01-03     32.449177     32.524032     31.049410     31.049410
# 1      2000-01-04     31.169176     32.786021     30.839818     32.486604
# 2      2000-01-05     31.925192     32.606361     29.043314     29.043314
# 3      2000-01-06     33.250103     34.417822     32.187175     32.187175
# 4      2000-01-07     35.914906     35.914906     33.399814     33.534553
#
# Price         Volume
# Ticker TATAMOTORS.NS
# 0            3528277
# 1            3544397
# 2            5849540
# 3           10274966
# 4           11477451

# %%
df.columns
# Out:
# MultiIndex([(  'Date',              ''),
#             ( 'Close', 'TATAMOTORS.NS'),
#             (  'High', 'TATAMOTORS.NS'),
#             (   'Low', 'TATAMOTORS.NS'),
#             (  'Open', 'TATAMOTORS.NS'),
#             ('Volume', 'TATAMOTORS.NS')],
#            names=['Price', 'Ticker'])

# %%
df.to_csv('TATAMOTORS.csv')
data01 = pd.read_csv('TATAMOTORS.csv')
# Remove the extra header row
data01 = data01.iloc[1:].copy()
# Convert relevant columns to numeric
data01[['Open', 'High', 'Low', 'Close', 'Volume']] = data01[['Open', 'High', 'Low', 'Close', 'Volume']].apply(pd.to_numeric)
data01.head()
# Out:
#   Price        Date      Close       High        Low       Open    Volume
# 1     0  2000-01-03  32.449177  32.524032  31.049410  31.049410   3528277
# 2     1  2000-01-04  31.169176  32.786021  30.839818  32.486604   3544397
# 3     2  2000-01-05  31.925192  32.606361  29.043314  29.043314   5849540
# 4     3  2000-01-06  33.250103  34.417822  32.187175  32.187175  10274966
# 5     4  2000-01-07  35.914906  35.914906  33.399814  33.534553  11477451

# %%
#candlesticks map
import plotly.graph_objects as go
fig = go.Figure(data=[go.Candlestick(x=data01['Date'],
                                     open=data01['Open'],
                                     high=data01['High'],
                                     low=data01['Low'],
                                     close=data01['Close'])])
fig.update_layout(title='TATAMOTORS',xaxis_rangeslider_visible=False)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
df = df.drop(['Date'], axis=1)
df.head()
# Out:
# /tmp/ipython-input-2218488136.py:1: PerformanceWarning:
#
# dropping on a non-lexsorted multi-index without a level parameter may impact performance.
# Price          Close          High           Low          Open        Volume
# Ticker TATAMOTORS.NS TATAMOTORS.NS TATAMOTORS.NS TATAMOTORS.NS TATAMOTORS.NS
# 0          32.449177     32.524032     31.049410     31.049410       3528277
# 1          31.169176     32.786021     30.839818     32.486604       3544397
# 2          31.925192     32.606361     29.043314     29.043314       5849540
# 3          33.250103     34.417822     32.187175     32.187175      10274966
# 4          35.914906     35.914906     33.399814     33.534553      11477451

# %%
plt.figure(figsize=(12,5))
plt.title(f'{stock} Closing Prices Overtime')
plt.grid(True)
plt.xlabel('Date')
plt.ylabel('Close Price(INR)')
plt.plot(df['Open'], label = f'{stock} Closing Price', linewidth = 1)
plt.legend()
plt.show()

# %%
plt.figure(figsize=(12,5))
plt.title(f'{stock} Opening Prices Overtime')
plt.grid(True)
plt.plot(df['Open'], label = f'{stock} Opening Price', linewidth = 1)
plt.legend()
plt.show()

# %%
plt.figure(figsize=(12,5))
plt.title(f'{stock} Stock Volume Overtime')
plt.grid(True)
plt.plot(df['Volume'], label = f'{stock} Stock Volume', linewidth = 1)
plt.legend()
plt.show()

# %%
plt.figure(figsize=(12,5))
plt.title(f'{stock} High Price Overtime')
plt.grid(True)
plt.plot(df['High'], label = f'{stock} High Price', linewidth = 1)
plt.legend()
plt.show()

# %%
plt.figure(figsize=(12,5))
plt.title(f'{stock} Low Price Overtime')
plt.grid(True)
plt.plot(df['Low'], label = f'{stock} Low Price', linewidth = 1)
plt.legend()
plt.show()

# %%
# find moving average
# [10,20,30,40,50,60,70,80,90]
# moving average for last 5 days will be null,null,null,null,30.0,40.0

temp_data = [10,20,30,40,50,60,70,80,90]
print(sum(temp_data[1:6])/5)
# Out:
# 40.0

# %%
import pandas as pd

df01 = pd.DataFrame(temp_data)

# %%
df01
# Out:
#     0
# 0  10
# 1  20
# 2  30
# 3  40
# 4  50
# 5  60
# 6  70
# 7  80
# 8  90

# %%
df01.rolling(5).mean()
# Out:
#       0
# 0   NaN
# 1   NaN
# 2   NaN
# 3   NaN
# 4  30.0
# 5  40.0
# 6  50.0
# 7  60.0
# 8  70.0

# %%
ma100 = df.Close.rolling(100).mean()
ma100
# Out:
# Ticker  TATAMOTORS.NS
# 0                 NaN
# 1                 NaN
# 2                 NaN
# 3                 NaN
# 4                 NaN
# ...               ...
# 6395       676.510610
# 6396       676.438933
# 6397       676.292483
# 6398       676.124358
# 6399       676.298849
#
# [6400 rows x 1 columns]

# %%
ma200 = df.Close.rolling(200).mean()
ma200
# Out:
# Ticker  TATAMOTORS.NS
# 0                 NaN
# 1                 NaN
# 2                 NaN
# 3                 NaN
# 4                 NaN
# ...               ...
# 6395       705.859208
# 6396       705.182628
# 6397       704.465440
# 6398       703.757739
# 6399       702.977939
#
# [6400 rows x 1 columns]

# %%
plt.figure(figsize=(12,5))
plt.plot(df.Close, label = f'{stock} actual close Price', linewidth = 1)
plt.plot(ma100, label = f'{stock} Moving Average for 100 Price', linewidth = 1)
plt.plot(ma200, label = f'{stock} Moving Average for 200 Price', linewidth = 1)
plt.legend()
plt.show()

# %%
# next 30 days stock. we use LSTM
ema100 = df.Close.ewm(span = 100, adjust= False).mean()
ema200 = df.Close.ewm(span = 200, adjust= False).mean()

# %%
df.pct_change()
# Out:
# Price          Close          High           Low          Open        Volume
# Ticker TATAMOTORS.NS TATAMOTORS.NS TATAMOTORS.NS TATAMOTORS.NS TATAMOTORS.NS
# 0                NaN           NaN           NaN           NaN           NaN
# 1          -0.039446      0.008055     -0.006750      0.046287      0.004569
# 2           0.024255     -0.005480     -0.058253     -0.105991      0.650363
# 3           0.041500      0.055555      0.108247      0.108247      0.756543
# 4           0.080144      0.043497      0.037675      0.041861      0.117031
# ...              ...           ...           ...           ...           ...
# 6395        0.017153      0.027680      0.023111      0.016517      1.276008
# 6396        0.035873      0.026788      0.000297     -0.000369      0.366522
# 6397       -0.015209     -0.003625      0.023622      0.034725     -0.483028
# 6398       -0.006090     -0.008348     -0.005806     -0.008925     -0.160945
# ...

# %%
plt.figure(figsize=(12,5))
plt.plot(df.Close, label = f'{stock} actual close Price', linewidth = 1)
plt.plot(ema100, label = f'{stock} ExponentialMoving Average for 100 Price', linewidth = 1)
plt.plot(ema200, label = f'{stock} Exponential Moving Average for 200 Price', linewidth = 1)
plt.legend()
plt.show()

# %%
# Divide the data for training and testing
data_training = pd.DataFrame(df['Close'][0:int(len(df)*0.70)])
data_testing = pd.DataFrame(df['Close'][int(len(df)*0.70):int(len(df))])

# %%
data_training.shape
# Out:
# (4480, 1)

# %%
data_testing.shape
# Out:
# (1920, 1)

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler(feature_range=(0,1))

# %%
data_training_array = scaler.fit_transform(data_training)

# %%
data_training_array
# Out:
# array([[0.04047617],
#        [0.03826992],
#        [0.03957301],
#        ...,
#        [0.70220047],
#        [0.69464263],
#        [0.68818873]])

# %%
data_training_array.shape[0]
# Out:
# 4480

# %%
x_train = []
y_train = []

for i in range(100, data_training_array.shape[0]):
  x_train.append(data_training_array[i-100:i])
  y_train.append(data_training_array[i,0])

x_train, y_train = np.array(x_train), np.array(y_train)

# %%
x_train.shape
# Out:
# (4380, 100, 1)

# %%
# Model Building
from keras.layers import Dense, Dropout, LSTM
from keras.models import Sequential

# %%
from ast import mod
# LSTM input -> 3D array(Batch_size, time_steps, seq_length)
# LSTM output -> can be 2D or 3D array
# If 2D-> it has (batch_size and units) and for 3D-> (batch_size,time_steps and units)

model = Sequential()

model.add(LSTM(units=50, activation='relu', return_sequences=True, input_shape=(x_train.shape[1],1)))
model.add(Dropout(0.2))

model.add(LSTM(units=60, activation='relu', return_sequences=True))
model.add(Dropout(0.3))

model.add(LSTM(units=80, activation='relu', return_sequences=True))
model.add(Dropout(0.4))

model.add(LSTM(units=120, activation='relu'))
model.add(Dropout(0.5))

model.add(Dense(units=1))
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/rnn/rnn.py:199: UserWarning:
#
# Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.

# %%
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ lstm (LSTM)                     │ (None, 100, 50)        │        10,400 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 100, 50)        │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_1 (LSTM)                   │ (None, 100, 60)        │        26,640 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 100, 60)        │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_2 (LSTM)                   │ (None, 100, 80)        │        45,120 │
# ...

# %%
model.compile(optimizer='adam', loss='mean_squared_error')
model.fit(x_train, y_train, epochs=50)
# Out:
# Epoch 1/50
# 137/137 ━━━━━━━━━━━━━━━━━━━━ 48s 258ms/step - loss: 0.0412
# Epoch 2/50
# 137/137 ━━━━━━━━━━━━━━━━━━━━ 42s 266ms/step - loss: 0.0057
# Epoch 3/50
# 137/137 ━━━━━━━━━━━━━━━━━━━━ 35s 259ms/step - loss: 0.0049
# Epoch 4/50
# 137/137 ━━━━━━━━━━━━━━━━━━━━ 39s 248ms/step - loss: 0.0046
# Epoch 5/50
# 137/137 ━━━━━━━━━━━━━━━━━━━━ 42s 259ms/step - loss: 0.0041
# Epoch 6/50
# 137/137 ━━━━━━━━━━━━━━━━━━━━ 41s 257ms/step - loss: 0.0040
# Epoch 7/50
# 137/137 ━━━━━━━━━━━━━━━━━━━━ 35s 258ms/step - loss: 0.0046
# Epoch 8/50
# 137/137 ━━━━━━━━━━━━━━━━━━━━ 41s 258ms/step - loss: 0.0037
# Epoch 9/50
# 137/137 ━━━━━━━━━━━━━━━━━━━━ 35s 259ms/step - loss: 0.0039
# Epoch 10/50
#  50/137 ━━━━━━━━━━━━━━━━━━━━ 22s 255ms/step - loss: 0.0032

# %%
past_100_days = data_training.tail(100)

# %%
final_df = pd.concat([past_100_days, data_testing], ignore_index=True)

# %%
from typing_extensions import final
final_df.head()

# %%
input_data = scaler.fit_transform(final_df)
input_data

# %%
x_test = []
y_test = []

for i in range(100, input_data.shape[0]):
  x_test.append(input_data[i-100:i])
  y_test.append(input_data[i,0])

x_test, y_test = np.array(x_test), np.array(y_test)

# %%
x_test.shape

# %%
y_predicted = model.predict(x_test)

# %%
y_predicted.shape

# %%
scaler.scale_

# %%
scalar_factor = 1/0.00091945
y_predicted = y_predicted*scalar_factor
y_test = y_test*scalar_factor

# %%
plt.figure(figsize=(12,5))
plt.plot(y_test, label = 'Original Price', linewidth = 1)
plt.plot(y_predicted, label = 'Predicted Price', linewidth = 1)
plt.legend()
plt.show()

# %%
model.save('TATAMOTORS.h5')
